# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("airline_passenger_satisfaction.csv")
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
## make a copy of data set.
df1=df.copy()
df1
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
## Check all information of data set.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
# Check the null values in dataset.
df1.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
# Check the no of rows and columns in a data set
df1.shape
# Out:
# (129880, 24)

# %%
df1["Arrival Delay"].value_counts()
# Out:
# Arrival Delay
# 0.0       72753
# 1.0        2747
# 2.0        2587
# 3.0        2442
# 4.0        2373
#           ...
# 1011.0        1
# 386.0         1
# 624.0         1
# 355.0         1
# 412.0         1
# Name: count, Length: 472, dtype: int64

# %%
df1["Arrival Delay"]=df1["Arrival Delay"].fillna(0).astype(int)

# %%
df1["Arrival Delay"].isnull().sum()
# Out:
# 0

# %%
df1["Arrival Delay"].dtype
# Out:
# dtype('int32')

# %%
df1.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction',
#        'Age_catagory', 'age_gen', 'age_gen_c_typ', 'G_cus_typ', 'cust_travel'],
#       dtype='object')

# %%
## Drop unnecessary columns.
df1.drop(['Gate Location','Baggage Handling','Leg Room Service',
'Food and Drink','On-board Service','In-flight Entertainment',
'Arrival Delay','Departure Delay',
'Departure and Arrival Time Convenience','In-flight Wifi Service'],axis=1,inplace=True)
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Seat Comfort  \
# 0                       3                 4                3             5
# 1                       2                 3                5             4
# 2                       4                 4                5             5
# 3                       2                 3                4             5
# 4                       3                 3                5             4
#
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Age Catagory

# %%
df1["Age"].unique()
# Out:
# array([48, 35, 41, 50, 49, 43, 60, 38, 28, 27, 24,  9, 52, 70, 61, 11, 42,
#        14, 56, 77, 51, 47, 58, 40, 21, 33, 39, 54, 46, 45, 23, 20, 44, 37,
#        36, 57, 31, 53, 25, 55, 72, 19, 65, 32, 80,  7, 34, 18, 12, 26, 17,
#        66, 68, 67, 59, 69, 16, 22, 64, 29, 10, 71, 30, 62, 63,  8, 15, 73,
#        78, 74, 79, 13, 76, 75, 85], dtype=int64)

# %%
df1["Age"].nunique()
# Out:
# 75

# %%
## # making a new column for age category
Age_catagory=[]
for i in df1["Age"]:
    if i>=0 and i <20:
        Age_catagory.append("0-20")
    elif i>=20 and i<40:
        Age_catagory.append("20-40")
    elif i>=40 and i<60:
        Age_catagory.append("40-60")
    elif i>=60 and i<80:
        Age_catagory.append("60-80")
    else:
        Age_catagory.append("80+")
df1["Age_catagory"]=Age_catagory  
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %%
df1["Gender"].value_counts()
# Out:
# Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64

# %%
sns.set(rc={'figure.figsize':(10,5)})
a=sns.countplot(x="Gender",data=df1,palette="rainbow_r")
for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# ## Here we are checking gender distribution according to age catagory:-

# %%
age_gender_grp=df1.groupby(["Age_catagory","Gender"],as_index=False)["ID"].count().sort_values(by="ID",ascending=False)

age_gender_grp
# Out:
#   Age_catagory  Gender     ID
# 4        40-60  Female  27009
# 5        40-60    Male  26593
# 2        20-40  Female  26586
# 3        20-40    Male  25297
# 0         0-20  Female   6154
# 6        60-80  Female   6072
# 1         0-20    Male   6026
# 7        60-80    Male   6008
# 8          80+  Female     78
# 9          80+    Male     57

# %%
sns.set(rc={'figure.figsize':(15,5)})

a=sns.barplot(data=age_gender_grp,y='ID',x='Age_catagory',hue='Gender',palette="tab20c")
for i in a.containers:
    a.bar_label(i)

# %%
df1['age_gen']=df1['Age_catagory']+'_'+df1['Gender']
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %% [markdown]
# ## Here we are cheacking type of customer according to age catagory:-

# %%
df1["Customer Type"].unique()
# Out:
# array(['First-time', 'Returning'], dtype=object)

# %%
cus_type=df1.groupby(['age_gen','Customer Type'],as_index=False)['ID'].count().sort_values(by='ID',ascending=False)
cus_type
# Out:
#          age_gen Customer Type     ID
# 9   40-60_Female     Returning  25040
# 11    40-60_Male     Returning  24994
# 7     20-40_Male     Returning  17179
# 5   20-40_Female     Returning  17027
# 4   20-40_Female    First-time   9559
# 6     20-40_Male    First-time   8118
# 13  60-80_Female     Returning   5817
# 15    60-80_Male     Returning   5780
# 1    0-20_Female     Returning   5126
# 3      0-20_Male     Returning   5048
# 8   40-60_Female    First-time   1969
# 10    40-60_Male    First-time   1599
# 0    0-20_Female    First-time   1028
# 2      0-20_Male    First-time    978
# 12  60-80_Female    First-time    255
# 14    60-80_Male    First-time    228
# 17    80+_Female     Returning     46
# 19      80+_Male     Returning     43
# 16    80+_Female    First-time     32
# 18      80+_Male    First-time     14

# %%
sns.set(rc={'figure.figsize':(15,5)})
a=sns.barplot(data=cus_type,x='age_gen',y='ID',hue='Customer Type',palette="cool")

for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# ##### As we can see ,the both male and females in age catagory of 40 to 60 have more customers in returning .

# %%
pd.set_option('display.max_columns',None) # for see all columns
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %% [markdown]
# # Type of Travel

# %%
df1["Type of Travel"].unique()
# Out:
# array(['Business', 'Personal'], dtype=object)

# %%
df1["Type of Travel"].value_counts()
# Out:
# Type of Travel
# Business    89693
# Personal    40187
# Name: count, dtype: int64

# %%
typ=df1["Type of Travel"].value_counts()
plt.figure(figsize=(10,5))
plt.pie(typ,labels=typ.index,autopct="%1.1f%%",startangle=90)
plt.title("Distribution of Type of Travels ")

plt.legend(loc='lower right', fontsize='smaller', title="Product Categories")

plt.show()

# %% [markdown]
# ##### AS we can se most of people travelled type is business.

# %% [markdown]
# ## Here we are just checking the travel type with the respect of Age catagory and gender.

# %%
Travel_type=df1.groupby(['age_gen','Type of Travel'],as_index=False)['ID'].count().sort_values(by='ID',ascending=False)
Travel_type
# Out:
#          age_gen Type of Travel     ID
# 8   40-60_Female       Business  20724
# 4   20-40_Female       Business  20338
# 10    40-60_Male       Business  20331
# 6     20-40_Male       Business  19033
# 9   40-60_Female       Personal   6285
# 7     20-40_Male       Personal   6264
# 11    40-60_Male       Personal   6262
# 5   20-40_Female       Personal   6248
# 1    0-20_Female       Personal   4141
# 3      0-20_Male       Personal   4129
# 13  60-80_Female       Personal   3431
# 15    60-80_Male       Personal   3427
# 12  60-80_Female       Business   2641
# 14    60-80_Male       Business   2581
# 0    0-20_Female       Business   2013
# 2      0-20_Male       Business   1897
# 16    80+_Female       Business     78
# 17      80+_Male       Business     57

# %%
# First, create the pivot table
pivot_table = Travel_type.pivot(index='age_gen', columns='Type of Travel',values="ID")

# Optionally, sort the values if needed
pivot_table_sorted=pivot_table.sort_values(by=pivot_table.columns.tolist(),ascending=False)
pivot_table_sorted
# Out:
# Type of Travel  Business  Personal
# age_gen
# 40-60_Female     20724.0    6285.0
# 20-40_Female     20338.0    6248.0
# 40-60_Male       20331.0    6262.0
# 20-40_Male       19033.0    6264.0
# 60-80_Female      2641.0    3431.0
# 60-80_Male        2581.0    3427.0
# 0-20_Female       2013.0    4141.0
# 0-20_Male         1897.0    4129.0
# 80+_Female          78.0       NaN
# 80+_Male            57.0       NaN

# %%
sns.set(rc={'figure.figsize':(15,5)})
a=sns.barplot(data=Travel_type,x='age_gen',y='ID',hue='Type of Travel',palette="winter")
for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# ##### AS we can see that, the both  female and male of age catagory 20 to 60 are more travelled for Business purposes.

# %% [markdown]
# ## Here we are checking that which age catagory travel in which class with the respect of gender.

# %%
df1["Class"].unique()
# Out:
# array(['Business', 'Economy', 'Economy Plus'], dtype=object)

# %%
cls=df1["Class"].value_counts()
plt.figure(figsize=(10,5))
plt.pie(cls,labels=cls.index,autopct="%1.1f%%",startangle=90)
plt.title("Distribution of class")

plt.legend(loc='lower right', fontsize='smaller', title="Product Categories")

plt.show()

# %% [markdown]
# ##### AS we can see most of people are travel in bussiness class.

# %%
clas_type=df1.groupby(['age_gen','Class'],as_index=False)['ID'].count().sort_values(by='ID',ascending=False)
clas_type
# Out:
#          age_gen         Class     ID
# 12  40-60_Female      Business  16275
# 15    40-60_Male      Business  15996
# 7   20-40_Female       Economy  12628
# 6   20-40_Female      Business  11912
# 9     20-40_Male      Business  11859
# 10    20-40_Male       Economy  11639
# 13  40-60_Female       Economy   9161
# 16    40-60_Male       Economy   9130
# 4      0-20_Male       Economy   4371
# 1    0-20_Female       Economy   4343
# 19  60-80_Female       Economy   3526
# 22    60-80_Male       Economy   3480
# 8   20-40_Female  Economy Plus   2046
# 21    60-80_Male      Business   1936
# 18  60-80_Female      Business   1899
# 11    20-40_Male  Economy Plus   1799
# 14  40-60_Female  Economy Plus   1573
# 17    40-60_Male  Economy Plus   1467
# 0    0-20_Female      Business   1118
# 3      0-20_Male      Business   1078
# 2    0-20_Female  Economy Plus    693
# 20  60-80_Female  Economy Plus    647
# 23    60-80_Male  Economy Plus    592
# 5      0-20_Male  Economy Plus    577
# ...

# %%
pv_class_typ=pivot_table = clas_type.pivot(index='age_gen', columns='Class',values="ID")

# Optionally, sort the values if needed
pivot_table_sort=pv_class_typ.sort_values(by=pv_class_typ.columns.tolist(),ascending=False)
pivot_table_sort
# Out:
# Class         Business  Economy  Economy Plus
# age_gen
# 40-60_Female     16275     9161          1573
# 40-60_Male       15996     9130          1467
# 20-40_Female     11912    12628          2046
# 20-40_Male       11859    11639          1799
# 60-80_Male        1936     3480           592
# 60-80_Female      1899     3526           647
# 0-20_Female       1118     4343           693
# 0-20_Male         1078     4371           577
# 80+_Female          59       12             7
# 80+_Male            28       19            10

# %%
sns.set(rc={'figure.figsize':(15,7)})
a=sns.barplot(data=clas_type,x="age_gen",y='ID',hue='Class',palette="summer_r")
plt.xticks(rotation=30)
for i in a.containers:
    a.bar_label(i,label_type='edge',  rotation=70)

# %% [markdown]
# ##### AS we can see that the both male and female of  age catagory of 40 to 60 are more travelled in bussiness class

# %% [markdown]
# ## Here we are checking that the customer type with gender are travel for bussiness or personal purpose.

# %%
df1['G_cus_typ']=df1['Customer Type']+'_'+df1['Gender']
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %%
customer_type=df1.groupby(['G_cus_typ','Type of Travel'],as_index=False)['ID'].count().sort_values(by="ID",ascending=False)
customer_type
# Out:
#            G_cus_typ Type of Travel     ID
# 6     Returning_Male       Business  33064
# 4   Returning_Female       Business  33050
# 5   Returning_Female       Personal  20006
# 7     Returning_Male       Personal  19980
# 0  First-time_Female       Business  12744
# 2    First-time_Male       Business  10835
# 3    First-time_Male       Personal    102
# 1  First-time_Female       Personal     99

# %%
a=sns.barplot(data=customer_type,x="G_cus_typ",y="ID",hue="Type of Travel")
sns.set(rc={'figure.figsize':(15,5)})
for i in a.containers:
    a.bar_label(i)
plt.show()

# %%
clss_typ=df1.groupby(["Customer Type","Class"],as_index=False)["ID"].count()
clss_typ
# Out:
#   Customer Type         Class     ID
# 0    First-time      Business   9231
# 1    First-time       Economy  13634
# 2    First-time  Economy Plus    915
# 3     Returning      Business  52929
# 4     Returning       Economy  44675
# 5     Returning  Economy Plus   8496

# %%
pivot_table = clss_typ.pivot(index='Customer Type', columns="Class",values="ID")

# Optionally, sort the values if needed
pivot_table_sorted=pivot_table.sort_values(by=pivot_table.columns.tolist(),ascending=False)
pivot_table_sorted
# Out:
# Class          Business  Economy  Economy Plus
# Customer Type
# Returning         52929    44675          8496
# First-time         9231    13634           915

# %%
df1['cust_travel']=df1['Customer Type']+'_'+df1['Type of Travel']
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %%
cust_tra=df1.groupby(["cust_travel","Class"],as_index=False)["ID"].count().sort_values(by="ID",ascending=False)
cust_tra
# Out:
#             cust_travel         Class     ID
# 6    Returning_Business      Business  50269
# 10   Returning_Personal       Economy  32821
# 1   First-time_Business       Economy  13450
# 7    Returning_Business       Economy  11854
# 0   First-time_Business      Business   9218
# 11   Returning_Personal  Economy Plus   4505
# 8    Returning_Business  Economy Plus   3991
# 9    Returning_Personal      Business   2660
# 2   First-time_Business  Economy Plus    911
# 4   First-time_Personal       Economy    184
# 3   First-time_Personal      Business     13
# 5   First-time_Personal  Economy Plus      4

# %%
a=sns.barplot(data=cust_tra,x="cust_travel",y="ID",hue="Class",)
sns.set(rc={'figure.figsize':(10,8)})
plt.xticks(rotation=90)
for i in a.containers:
    a.bar_label(i,label_type='edge',  rotation=70)
plt.show()

# %%
pd.set_option('display.max_columns',None) # for see all columns
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %% [markdown]
# # Satisfaction

# %%
df1["Satisfaction"].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: count, dtype: int64

# %%
Satisfaction_of_people=df1["Satisfaction"].value_counts()
plt.figure(figsize=(10,5))
plt.pie(Satisfaction_of_people,labels=Satisfaction_of_people.index,autopct="%1.1f%%",startangle=90)
plt.title("Satisfaction_of_people")

plt.legend(loc='lower right', fontsize='smaller', title="Satisfaction")

plt.show()

# %% [markdown]
# ##### As we can see that ,the most of peoples are Neutral or Dissatisfied

# %% [markdown]
# # Gender wise Satisfaction:-

# %%
gender_sat=df1.groupby(["Satisfaction","Gender"],as_index=False)["ID"].count()

gender_sat.sort_values(by="ID",ascending=False)
# Out:
#               Satisfaction  Gender     ID
# 0  Neutral or Dissatisfied  Female  37630
# 1  Neutral or Dissatisfied    Male  35822
# 2                Satisfied  Female  28269
# 3                Satisfied    Male  28159

# %%
sns.set(rc={'figure.figsize':(15,5)})

a=sns.barplot(data=gender_sat,y='ID',x='Satisfaction',hue='Gender',palette="tab20c")
for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# ##### As we can see that more female are dissatisfied.

# %% [markdown]
# # Age catagory  and Gender wise Satisfaction

# %%
Age_c_sat=df1.groupby(["age_gen","Satisfaction"],as_index=False)["ID"].count().sort_values(by="ID",ascending=False)

Age_c_sat
# Out:
#          age_gen             Satisfaction     ID
# 4   20-40_Female  Neutral or Dissatisfied  16613
# 9   40-60_Female                Satisfied  15522
# 11    40-60_Male                Satisfied  15401
# 6     20-40_Male  Neutral or Dissatisfied  15311
# 8   40-60_Female  Neutral or Dissatisfied  11487
# 10    40-60_Male  Neutral or Dissatisfied  11192
# 7     20-40_Male                Satisfied   9986
# 5   20-40_Female                Satisfied   9973
# 0    0-20_Female  Neutral or Dissatisfied   5023
# 2      0-20_Male  Neutral or Dissatisfied   4917
# 12  60-80_Female  Neutral or Dissatisfied   4451
# 14    60-80_Male  Neutral or Dissatisfied   4360
# 15    60-80_Male                Satisfied   1648
# 13  60-80_Female                Satisfied   1621
# 1    0-20_Female                Satisfied   1131
# 3      0-20_Male                Satisfied   1109
# 16    80+_Female  Neutral or Dissatisfied     56
# 18      80+_Male  Neutral or Dissatisfied     42
# ...

# %%
# First, create the pivot table
pivot_table = Age_c_sat.pivot(index='age_gen', columns="Satisfaction",values="ID")

# Optionally, sort the values if needed
pivot_table_sorted=pivot_table.sort_values(by=pivot_table.columns.tolist(),ascending=False)
pivot_table_sorted
# Out:
# Satisfaction  Neutral or Dissatisfied  Satisfied
# age_gen
# 20-40_Female                    16613       9973
# 20-40_Male                      15311       9986
# 40-60_Female                    11487      15522
# 40-60_Male                      11192      15401
# 0-20_Female                      5023       1131
# 0-20_Male                        4917       1109
# 60-80_Female                     4451       1621
# 60-80_Male                       4360       1648
# 80+_Female                         56         22
# 80+_Male                           42         15

# %%
sns.set(rc={'figure.figsize':(15,5)})

a=sns.barplot(data=Age_c_sat,y='ID',x='age_gen',hue="Satisfaction",palette="tab20c")
for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# ##### As we can see that, In the age catagory of 20 to 40 female are more Dissatisfied.

# %% [markdown]
# # Here we check the Satisfaction according to Customer Type

# %%
cus_type_sat=df1.groupby(['Satisfaction','Customer Type'],as_index=False)['ID'].count()
cus_type_sat.sort_values(by='ID',ascending=False)
# Out:
#               Satisfaction Customer Type     ID
# 1  Neutral or Dissatisfied     Returning  55372
# 3                Satisfied     Returning  50728
# 0  Neutral or Dissatisfied    First-time  18080
# 2                Satisfied    First-time   5700

# %%
pivot_table_of_satic =cus_type_sat.pivot(index='Customer Type', columns="Satisfaction",values="ID")

# Optionally, sort the values if needed
pivot_table_sorted=pivot_table_of_satic.sort_values(by=pivot_table_of_satic.columns.tolist(),ascending=False)
pivot_table_sorted
# Out:
# Satisfaction   Neutral or Dissatisfied  Satisfied
# Customer Type
# Returning                        55372      50728
# First-time                       18080       5700

# %%
sns.set(rc={'figure.figsize':(15,5)})

a=sns.barplot(data=cus_type_sat,y='ID',x='Customer Type',hue="Satisfaction",palette="cool")
for i in a.containers:
    a.bar_label(i)

# %% [markdown]
# # Here we check the Satisfaction according to Customer Type ,gender and age

# %%
df1['age_gen_c_typ']=df1['age_gen']+'_'+df1['Customer Type']
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2              5                                       3
# 1               26             39                                       2
# 2                0              0                                       4
# 3                0              0                                       2
# 4                0              1                                       3
#
# ...

# %%
cus_type_satisfiction=df1.groupby(['Satisfaction','age_gen_c_typ'],as_index=False)['ID'].count().sort_values(by='ID',ascending=False)

cus_type_satisfiction
# Out:
#                Satisfaction            age_gen_c_typ     ID
# 29                Satisfied   40-60_Female_Returning  15112
# 31                Satisfied     40-60_Male_Returning  15034
# 11  Neutral or Dissatisfied     40-60_Male_Returning   9960
# 9   Neutral or Dissatisfied   40-60_Female_Returning   9928
# 5   Neutral or Dissatisfied   20-40_Female_Returning   9285
# 7   Neutral or Dissatisfied     20-40_Male_Returning   9281
# 27                Satisfied     20-40_Male_Returning   7898
# 25                Satisfied   20-40_Female_Returning   7742
# 4   Neutral or Dissatisfied  20-40_Female_First-time   7328
# 6   Neutral or Dissatisfied    20-40_Male_First-time   6030
# 1   Neutral or Dissatisfied    0-20_Female_Returning   4264
# 13  Neutral or Dissatisfied   60-80_Female_Returning   4230
# 3   Neutral or Dissatisfied      0-20_Male_Returning   4192
# 15  Neutral or Dissatisfied     60-80_Male_Returning   4173
# 24                Satisfied  20-40_Female_First-time   2231
# ...

# %%
pivot_table_of_ct_satic =cus_type_satisfiction.pivot(index='age_gen_c_typ', columns="Satisfaction",values="ID")

# Optionally, sort the values if needed
pivot_table_sorted=pivot_table_of_ct_satic.sort_values(by=pivot_table_of_ct_satic.columns.tolist(),ascending=False)
pivot_table_sorted
# Out:
# Satisfaction             Neutral or Dissatisfied  Satisfied
# age_gen_c_typ
# 40-60_Male_Returning                        9960      15034
# 40-60_Female_Returning                      9928      15112
# 20-40_Female_Returning                      9285       7742
# 20-40_Male_Returning                        9281       7898
# 20-40_Female_First-time                     7328       2231
# 20-40_Male_First-time                       6030       2088
# 0-20_Female_Returning                       4264        862
# 60-80_Female_Returning                      4230       1587
# 0-20_Male_Returning                         4192        856
# 60-80_Male_Returning                        4173       1607
# 40-60_Female_First-time                     1559        410
# 40-60_Male_First-time                       1232        367
# 0-20_Female_First-time                       759        269
# 0-20_Male_First-time                         725        253
# ...

# %%
sns.set(rc={'figure.figsize':(18,10)})

a=sns.barplot(data=cus_type_satisfiction,y='ID',x='age_gen_c_typ',hue="Satisfaction",palette="tab20c_r")
for i in a.containers:
    a.bar_label(i)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### As we can see that ,the females of age catagory 40 to 60 in returning type of customer are more Satisfied.

# %%
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Seat Comfort  \
# 0                       3                 4                3             5
# 1                       2                 3                5             4
# 2                       4                 4                5             5
# 3                       2                 3                4             5
# 4                       3                 3                5             4
#
# ...
